# %% [markdown]
# # Who Follows Trump on Twitter? A Graphical Approach to Social Media Analysis

# %% [markdown]
# In this notebook, we will try, using network analysis libraries, to cluster social network users and produce a simple analysis of these clusters. The goal is to show you how to use `networkx` to discover clusters in any network.

# %% [markdown]
# ### First get the data

# %%
from zipfile import ZipFile
import urllib2
from StringIO import StringIO
import os
import time

DATA_URL = 'https://www.dropbox.com/s/mow0ru0duq3l1dl/trump_followers.zip?dl=1'
DATA_DIR = './data'

def download_and_extract_content(url, directory):
    print 'Downloading the data...'
    s = time.time()
    response = urllib2.urlopen(url)
    content = response.read()
    print 'Finished in %.2f seconds.' % (time.time()-s)
    
    print 'Extracting the archive to %s' % directory
    s = time.time()
    zip_data = StringIO()
    zip_data.write(content)
    
    zip_file = ZipFile(zip_data)
    zip_file.extractall(path=directory)
    print 'Done in %.2f seconds.' % (time.time()-s)

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    download_and_extract_content(DATA_URL, DATA_DIR)
# Out:
# Downloading the data...
# Finished in 56.31 seconds.
# Extracting the archive to ./data
# Done in 795.38 seconds.

# %% [markdown]
# ### Helper functions to interact with and read the data

# %%
import codecs
import json
from os import listdir
from os.path import isfile, join

def get_trump_followers(directory=DATA_DIR+'/friends'):
    for fname in listdir(directory):
        fpath = join(directory, fname)
        if isfile(fpath):
            # make sure the file contains some ids as some will be empty
            # due to the account being private
            with open(fpath, 'r') as f:
                if f.read().strip() != '':
                    yield fname, fpath

def get_friends(trump_follower, fpath):
    with open(fpath, 'r') as f:
        ffriends = f.read().split(',')
    for friend in ffriends:
        if friend != '':
            yield friend

def get_user_data(user, directory=DATA_DIR+'/users'):
    fpath = join(directory, user)
    if not isfile(fpath):
        return None
    with codecs.open(fpath, 'r', 'utf-8') as f:
        return json.load(f)

def get_users_data(users):
    for u in users:
        yield get_user_data(user)

def id_to_str(id_):
    data = get_user_data(id_)
    if not data is None:
        return '%s' % data['name']
    return id_

def id_to_screenname(id_):
    data = get_user_data(id_)
    if not data is None:
        return '%s' % data['screen_name']
    return ''

# %% [markdown]
# ### Helpers to build the network

# %%
import networkx as nx # pip install networkx
import community      # pip install python-louvain
import numpy as np    # pip install numpy

num_trump_followers = 0 # this counts the final number of Trump followers in the network

def get_followers_and_friends():
    followers = dict()
    their_friends = dict()
    for trump_follower, fpath in get_trump_followers():
        followers[trump_follower] = set()
        for friend in get_friends(trump_follower, fpath):
            followers[trump_follower].add(friend)

            if friend not in their_friends:
                their_friends[friend] = set()
            their_friends[friend].add(trump_follower)
        
    return followers, their_friends

def get_outliers(followers, their_friends, min_num_followers, num_supernodes_to_drop):
    ''' There are 3 outlier detection steps that we'll do:
        1. For Trump's followers, any that has less than 25% friends of the overall
           counts, or any that has more than (1.5 * Interquartile range) friends.
        2. For their friends: anyone that has less than X followers in total, where X
           is a parameter. The idea is to remove those that have very few followers as
           they won't be useful in our analysis.
        3. The supernodes: nodes that are connected to a LOT of other nodes. Trump will
           likely be at the top, but removing others as well should help get rid of some
           noise.
    '''
    
    print 'Outlier detection...'
    outliers = set()
    
    # 1.
    friends_counts = [len(ffriends) for follower, ffriends in followers.iteritems()]
    friends_q1, friends_q3 = np.percentile(friends_counts, [25, 75])
    iqr = friends_q3 - friends_q1
    min_friends = friends_q1
    max_friends = friends_q3 + 1.5 * iqr
    print '\tAllowing followers with friends between %.1f and %.1f' % (min_friends, max_friends)
    
    outliers |= {follower for follower, ffriends in followers.iteritems()
                               if len(ffriends) < min_friends or len(ffriends) > max_friends}
    
    print '\tNumber of outlier Trump followers that will be ignored: %d' % len(outliers)
    
    # 2.
    friends_outliers = {friend for friend, ffollowers in their_friends.iteritems()
                               if len(ffollowers) < min_num_followers}
    print '\tNumber of outlier friends of Trump\'s followers that will be ignored: %d' % len(friends_outliers)
    
    outliers |= friends_outliers
    
    # 3.
    top_followed = sorted(their_friends.keys(), key=lambda x: len(their_friends[x]), reverse=True)
    top_followed = top_followed[:num_supernodes_to_drop]
    print '\tRemoving top %d followed accounts:' % num_supernodes_to_drop
    print ', '.join([id_to_screenname(id_) for id_ in top_followed])
    
    outliers |= set(top_followed)
    
    return outliers

def get_network(followers, outliers=None):
    global num_trump_followers
    num_trump_followers = 0
    
    if outliers is None:
        outliers = set()
    
    G = nx.DiGraph()
    for trump_follower, ffriends in followers.iteritems():
        if trump_follower in outliers:
            continue
        num_trump_followers += 1
        
        for friend in ffriends:
            if friend in outliers:
                continue
            
            G.add_edge(trump_follower, friend)
            
            # add some attributes to the nodes so we can inspect the nodes in Gephi
            # this is a slow IO process so comment out if you don't care about this
            follower_data = get_user_data(trump_follower)
            friend_data   = get_user_data(friend)
            
            fo_name  = follower_data['name']        if follower_data else ''
            fo_sname = follower_data['screen_name'] if follower_data else ''
            fr_name  = friend_data['name']          if friend_data else ''
            fr_sname = friend_data['screen_name']   if friend_data else ''

            G.node[trump_follower]['name'] = fo_name
            G.node[trump_follower]['screenname'] = fo_sname
            G.node[friend]['name'] = fr_name
            G.node[friend]['screenname'] = fr_sname
        
    print 'Number of Trump followers in the network:', num_trump_followers
    print 'Number of nodes:', G.order()
    print 'Number of edges:', G.size()
    print 'Average degree:', np.array(nx.degree(G).values()).mean()
    
    return G

def build_network():
        
    # 1. first get all of trump's followers and their friends
    followers, their_friends = get_followers_and_friends()
    print 'Found %d Trump followers.' % len(followers)
    
    # 2. then get outliers
    outliers = get_outliers(followers, their_friends, min_num_followers=10, num_supernodes_to_drop=50)
    print '\tTotal outlier nodes: %d' % len(outliers) 

    # 3. finally, build the graph from the remaining followers
    return get_network(followers, outliers)

# %%
G = build_network()
# Out:
# Found 12902 Trump followers.
# Outlier detection...
# 	Allowing followers with friends between 48.0 and 822.4
# 	Number of outlier Trump followers that will be ignored: 4619
# 	Number of outlier friends of Trump's followers that will be ignored: 2092741
# 	Removing top 50 followed accounts:
# realDonaldTrump, BarackObama, cnnbrk, jimmyfallon, TheEllenShow, nytimes, katyperry, taylorswift13, CNN, BillGates, Forbes, KimKardashian, ladygaga, justinbieber, WSJ, jtimberlake, FoxNews, SportsCenter, YouTube, KingJames, Oprah, espn, rihanna, KevinHart4real, TheEconomist, WhiteHouse, ActuallyNPH, kanyewest, ConanOBrien, selenagomez, danieltosh, BBCBreaking, richardbranson, Reuters, NFL, Drake, HillaryClinton, NASA, MileyCyrus, POTUS, twitter, khloekardashian, MarketWatch, NBA, kourtneykardash, blakeshelton, wizkhalifa, BBCWorld, britneyspears, TIME
# 	Total outlier nodes: 2097261
# Number of Trump followers in the network: 8178
# Number of nodes: 48008
# Number of edges: 813916
# Average degree: 33.9075154141

# %% [markdown]
# ### Optional: Save the network for use with Gephi

# %%
nx.write_graphml(G, DATA_DIR+'/network.graphml')

# %% [markdown]
# ### Calculate the communities in the network

# %%
communities = community.best_partition(G.to_undirected(), resolution=1.0)
print 'Number of communities:', len(set(communities.values()))
# Out:
# Number of communities: 18

# %% [markdown]
# ### Calculate the size of each community and how many trump followers are in each

# %%
sizes = dict()
for node, c in communities.iteritems():
    if not c in sizes:
        sizes[c] = 0
    sizes[c] += 1

trump_followers = map(lambda (trump_follower, fpath): trump_follower,get_trump_followers())
followers_per_community = dict()
for c in sizes:
    trump_followers_in_community = filter(lambda follower: communities.get(follower, -1)==c, trump_followers)
    followers_per_community[c] = len(trump_followers_in_community)

# %% [markdown]
# ### Compute a centrality score for each node

# %%
# scores = nx.eigenvector_centrality(G, max_iter=1000)
scores = nx.pagerank(G)

# %% [markdown]
# # Results

# %% [markdown]
# ### For each community, print the top N nodes based on their scores

# %%
N = 10

for c in sorted(followers_per_community.keys(), key=followers_per_community.get, reverse=True):

    print 'Community %d' % (c,)
    
    percent_overall = 100.0 * sizes[c] / len(communities)
    percent_trump   = 100.0 * followers_per_community[c] / num_trump_followers
    
    print '\tNumber of nodes: %d (%%%.2f), out of which, %d are Trump followers (%%%.2f)' % \
                (sizes[c], percent_overall, followers_per_community[c], percent_trump)
    
    nodes = filter(lambda n: communities[n]==c, scores.keys())
    print '\tTop %d Nodes (PageRank):' % N
    for node in sorted(nodes, key=scores.get, reverse=True)[:N]:
        print '\t\t%s\t%.12f\t' % (id_to_str(node), scores[node])
# Out:
# Community 4
# 	Number of nodes: 11234 (%23.40), out of which, 1742 are Trump followers (%21.30)
# 	Top 10 Nodes (PageRank):
# 		Dr. Ben Carson	0.000265679505
# 		Ted Cruz	0.000217594350
# 		Marco Rubio	0.000190006283
# 		SHAQ	0.000174564531
# 		Kevin Durant	0.000149938824
# 		Megyn Kelly	0.000140340060
# 		Tiger Woods	0.000136802297
# 		Kobe Bryant	0.000125326549
# 		Sean Hannity	0.000124281932
# 		Mitt Romney	0.000115294762
# Community 1
# 	Number of nodes: 5387 (%11.22), out of which, 1547 are Trump followers (%18.92)
# 	Top 10 Nodes (PageRank):
# 		Ariana Grande	0.000299297842
# 		Kendall	0.000281915571
# 		Kylie Jenner	0.000278941210
# 		Stephen Colbert	0.000271917690
# 		Aziz Ansari	0.000269557233
# 		Seth MacFarlane	0.000247524672
# 		Funny Or Die	0.000246660854
# 		Mark Cuban	0.000237261108
# 		Bill Clinton	0.000228092338
# 		UberFacts	0.000227512505
# Community 5
# 	Number of nodes: 7376 (%15.36), out of which, 1352 are Trump followers (%16.53)
# 	Top 10 Nodes (PageRank):
# 		Anderson Cooper	0.000215303009
# 		Ivanka Trump	0.000169081677
# 		The Onion	0.000166570082
# 		Tom Hanks	0.000159029509
# 		Jimmy Kimmel	0.000154044263
# 		Jennifer Lopez	0.000153122863
# 		Breaking News	0.000143274536
# 		Sarah Silverman	0.000141856638
# 		Charlie Sheen	0.000136508087
# 		Leonardo DiCaprio	0.000135354423
# Community 0
# 	Number of nodes: 6973 (%14.52), out of which, 1251 are Trump followers (%15.30)
# 	Top 10 Nodes (PageRank):
# 		Bernie Sanders	0.000195974588
# 		National Geographic	0.000150180842
# 		Bernie Sanders	0.000123649310
# 		Vine	0.000114425594
# 		Emma Watson	0.000111081139
# 		Bill Maher	0.000105608032
# 		US Dept of Interior	0.000082893291
# 		Cameron Dallas	0.000081937586
# 		zayn	0.000076891603
# 		Meninist	0.000075935942
# Community 6
# 	Number of nodes: 4903 (%10.21), out of which, 588 are Trump followers (%7.19)
# 	Top 10 Nodes (PageRank):
# 		Cristiano Ronaldo	0.000141683844
# 		Russell Brand	0.000116915309
# 		Ricky Gervais	0.000101438605
# 		Piers Morgan	0.000086434552
# 		Premier League	0.000081572002
# 		Simon Cowell	0.000079066368
# 		Wayne Rooney	0.000071539948
# 		Neymar Jr	0.000071312720
# 		Jamie Oliver	0.000068589593
# 		UK Prime Minister	0.000065357484
# Community 7
# 	Number of nodes: 3142 (%6.54), out of which, 412 are Trump followers (%5.04)
# 	Top 10 Nodes (PageRank):
# 		Lil Wayne WEEZY F	0.000271669481
# 		J. Cole	0.000121862331
# 		Snoop Dogg	0.000117419160
# 		Sean Diddy Combs	0.000091970148
# 		Chris Brown	0.000087935575
# 		Kendrick Lamar	0.000078069510
# 		Big Sean	0.000076612663
# 		Pharrell Williams	0.000075042693
# 		Joyce Meyer	0.000074691009
# 		Ludacris	0.000072633429
# Community 12
# 	Number of nodes: 2738 (%5.70), out of which, 368 are Trump followers (%4.50)
# 	Top 10 Nodes (PageRank):
# 		Dwayne Johnson	0.000105385695
# 		Neil deGrasse Tyson	0.000096743917
# 		Robert Downey Jr	0.000082959485
# 		Edward Snowden	0.000066213794
# 		Rockstar Games	0.000051788807
# 		John Cena	0.000049471933
# 		chris pratt	0.000049125146
# 		Triple H	0.000046262105
# 		IGN	0.000045064790
# 		Game Of Thrones	0.000044524666
# Community 11
# 	Number of nodes: 1635 (%3.41), out of which, 250 are Trump followers (%3.06)
# 	Top 10 Nodes (PageRank):
# 		T.D. Jakes	0.000047471363
# 		Channels Television	0.000042084415
# 		Samsung Mobile US	0.000040690160
# 		BBC Africa	0.000038740223
# 		Uhuru Kenyatta	0.000038710728
# 		Sahara Reporters	0.000037413252
# 		The Punch Newspapers	0.000036055633
# 		Prof Yemi Osinbajo	0.000035994494
# 		Linda Ikeji	0.000035963391
# 		DON JAZZY	0.000034847556
# Community 15
# 	Number of nodes: 1053 (%2.19), out of which, 142 are Trump followers (%1.74)
# 	Top 10 Nodes (PageRank):
# 		أحمد الشقيري	0.000048253977
# 		HH Sheikh Mohammed	0.000047404070
# 		العربية عاجل	0.000046249291
# 		قناة الجزيرة	0.000043305876
# 		قناة العربية	0.000043288314
# 		د. #عائض_القرني	0.000039170757
# 		CNN بالعربية	0.000037973794
# 		Elissa	0.000037894363
# 		Nancy Ajram	0.000037257490
# 		مشاري راشد العفاسي	0.000036964831
# Community 10
# 	Number of nodes: 1175 (%2.45), out of which, 136 are Trump followers (%1.66)
# 	Top 10 Nodes (PageRank):
# 		Justin Trudeau	0.000041549540
# 		TheStreet	0.000038301963
# 		ABC 7 Chicago	0.000038160817
# 		Chris Hadfield	0.000034140476
# 		Carl Icahn	0.000032660280
# 		Herb Greenberg	0.000032598575
# 		zerohedge	0.000032342688
# 		CBC News	0.000031197980
# 		CP24	0.000030728344
# 		Toronto Blue Jays	0.000030697539
# Community 17
# 	Number of nodes: 582 (%1.21), out of which, 100 are Trump followers (%1.22)
# 	Top 10 Nodes (PageRank):
# 		Dilma Rousseff	0.000033744611
# 		Anderson Silva	0.000029205499
# 		Дмитрий Медведев	0.000028545275
# 		VEJA	0.000027969322
# 		Президент России	0.000027772074
# 		Владимир Путин	0.000026981205
# 		Marcelo Tas	0.000026823211
# 		Gisele Bündchen	0.000026731738
# 		G1	0.000026594735
# 		ForbesRussia	0.000026321425
# Community 13
# 	Number of nodes: 532 (%1.11), out of which, 98 are Trump followers (%1.20)
# 	Top 10 Nodes (PageRank):
# 		UberSocial	0.000047761509
# 		detikcom	0.000033816948
# 		AGNEZ MO	0.000031862114
# 		tvOneNews	0.000030259757
# 		METRO TV	0.000030236118
# 		TMC Polda Metro Jaya	0.000029553636
# 		Kompas.com	0.000029524931
# 		Joko Widodo	0.000029103281
# 		S. B. Yudhoyono	0.000028943004
# 		Cinema XXI	0.000028803230
# Community 8
# 	Number of nodes: 344 (%0.72), out of which, 65 are Trump followers (%0.79)
# 	Top 10 Nodes (PageRank):
# 		9GAG	0.000055999719
# 		Paulo Coelho	0.000052630003
# 		jose marie viceral	0.000031775914
# 		Angel Locsin	0.000031192969
# 		GMA News	0.000028441290
# 		Enrique Gil	0.000027536812
# 		Yeng Constantino	0.000027459528
# 		Maine Mendoza	0.000027452776
# 		ABS-CBN News	0.000027297779
# 		Bianca Gonzalez	0.000027169533
# Community 9
# 	Number of nodes: 177 (%0.37), out of which, 36 are Trump followers (%0.44)
# 	Top 10 Nodes (PageRank):
# 		纽约时报中文网	0.000025965187
# 		美国驻华使领馆 US MissionCN	0.000025737011
# 		BBC Chinese	0.000025363906
# 		FT China	0.000024945707
# 		佐々木俊尚	0.000024399582
# 		Twitter 简体中文	0.000023883272
# 		Translator	0.000023584140
# 		tenki.jp地震情報	0.000023488711
# 		华尔街日报中文网	0.000023429898
# 		我们爱讲冷笑话	0.000023334442
# Community 2
# 	Number of nodes: 264 (%0.55), out of which, 32 are Trump followers (%0.39)
# 	Top 10 Nodes (PageRank):
# 		Malcolm Turnbull	0.000027317463
# 		Kevin Rudd	0.000026412860
# 		ABC News	0.000024928091
# 		AFL	0.000022909477
# 		The Age	0.000022759533
# 		smh.com.au	0.000022495417
# 		ABC News 24	0.000022492680
# 		Tony Abbott	0.000022421782
# 		Rove McManus	0.000022291787
# 		The Australian	0.000022237749
# Community 14
# 	Number of nodes: 330 (%0.69), out of which, 20 are Trump followers (%0.24)
# 	Top 10 Nodes (PageRank):
# 		عادل علي بن علي	0.000023954048
# 		David Copperfield	0.000023541648
# 		LeBron James ☄	0.000023184262
# 		Jay Williams	0.000021911485
# 		Pottery Posts	0.000021665570
# 		Couples	0.000021637407
# 		Angel Rivera	0.000021588776
# 		Daniel Newman	0.000021480709
# 		✰⌒*✰ ƬꃅᏘƬ ᎶᎥℛᎲ ✰⌒*✰	0.000021367397
# 		Sean Maxwell	0.000021286019
# Community 3
# 	Number of nodes: 93 (%0.19), out of which, 18 are Trump followers (%0.22)
# 	Top 10 Nodes (PageRank):
# 		Sıla Gençoğlu	0.000027531617
# 		Ayse Arman	0.000027497309
# 		Cem Yılmaz	0.000025506434
# 		Recep Tayyip Erdoğan	0.000024822776
# 		cüneyt özdemir	0.000024418765
# 		Abdullah Gül	0.000023319913
# 		Galatasaray SK	0.000023018483
# 		ahmet hakan	0.000022642578
# 		Ahmet Kural	0.000022630152
# 		fatih portakal	0.000022406632
# Community 16
# 	Number of nodes: 70 (%0.15), out of which, 15 are Trump followers (%0.18)
# 	Top 10 Nodes (PageRank):
# 		นิชคุณ Buck หรเวชกุล	0.000024325253
# 		Andrew Biggs	0.000023192641
# 		Opal Panisara	0.000023125482
# 		Woody Milintachinda	0.000022975364
# 		กระทู้เด็ดพันทิป	0.000022703547
# 		JS100	0.000022493237
# 		cuttO	0.000022410203
# 		Thairath_News	0.000022354556
# 		Major Cineplex	0.000022194954
# 		เต๋อ ฉันทวิชช์	0.000022100710

# %% [markdown]
# ### The final result: for each community, calculate the top N friends for Trump's followers in that community.

# %%
N = 10

def get_friends_counts_from_graph(users, G):
    friends = dict()
    for u in users:
        for _, f in G.out_edges(u):
            if not f in friends:
                friends[f] = 0
            friends[f] += 1
    return friends

for community in sorted(followers_per_community.keys(), key=followers_per_community.get, reverse=True):
    print 'Community %d' % (community,)
    
    percent_overall = 100.0 * sizes[community] / len(communities)
    percent_trump   = 100.0 * followers_per_community[community] / num_trump_followers
    
    print '\tNumber of nodes: %d (%%%.2f), out of which, %d are Trump followers (%%%.2f)' % \
                (sizes[community], percent_overall, followers_per_community[community], percent_trump)
    
    trump_followers_in_community = filter(lambda follower: communities.get(follower, -1)==community, trump_followers)
    
    friend_counts = get_friends_counts_from_graph(trump_followers_in_community, G)
    print '\tTotal number of friends: %d' % len(friend_counts)
    print '\tTop %d Friends of Trump\'s followers:' % N
    for friend in sorted(friend_counts.keys(), key=friend_counts.get, reverse=True)[:N]:
        print '\t\t%s\t%d' % (id_to_str(friend), friend_counts[friend])
# Out:
# Community 4
# 	Number of nodes: 11234 (%23.40), out of which, 1742 are Trump followers (%21.30)
# 	Total number of friends: 21683
# 	Top 10 Friends of Trump's followers:
# 		Adam Schefter	431
# 		Dr. Ben Carson	424
# 		Sean Hannity	407
# 		Megyn Kelly	392
# 		Marco Rubio	386
# 		Ted Cruz	358
# 		Ann Coulter	328
# 		Bill O'Reilly	320
# 		Mark Cuban	314
# 		SHAQ	299
# Community 1
# 	Number of nodes: 5387 (%11.22), out of which, 1547 are Trump followers (%18.92)
# 	Total number of friends: 15483
# 	Top 10 Friends of Trump's followers:
# 		Aziz Ansari	518
# 		United Nations	470
# 		Mike Bloomberg	438
# 		Vogue Magazine	396
# 		Mindy Kaling	395
# 		NPR	390
# 		Mark Cuban	389
# 		Twitter TV	383
# 		CHANEL	382
# 		Funny Or Die	379
# Community 5
# 	Number of nodes: 7376 (%15.36), out of which, 1352 are Trump followers (%16.53)
# 	Total number of friends: 20753
# 	Top 10 Friends of Trump's followers:
# 		ashton kutcher	423
# 		Tom Hanks	403
# 		Ryan Seacrest	396
# 		Anderson Cooper	362
# 		P!nk	358
# 		Ivanka Trump	350
# 		Jim Carrey	344
# 		Jimmy Kimmel	328
# 		Charlie Sheen	327
# 		People Magazine	316
# Community 0
# 	Number of nodes: 6973 (%14.52), out of which, 1251 are Trump followers (%15.30)
# 	Total number of friends: 16668
# 	Top 10 Friends of Trump's followers:
# 		Bernie Sanders	241
# 		Kylie Jenner	215
# 		Ariana Grande	215
# 		Dr. Ben Carson	212
# 		Kendall	201
# 		Cameron Dallas	186
# 		Ted Cruz	173
# 		National Geographic	173
# 		Connor Franta	160
# 		Anderson Cooper	152
# Community 6
# 	Number of nodes: 4903 (%10.21), out of which, 588 are Trump followers (%7.19)
# 	Total number of friends: 14285
# 	Top 10 Friends of Trump's followers:
# 		Lord Sugar	205
# 		Wayne Rooney	170
# 		Cristiano Ronaldo	166
# 		Piers Morgan	165
# 		Jonathan Ross	159
# 		Gary Lineker	159
# 		Jeremy Clarkson	152
# 		Rio Ferdinand	150
# 		Ricky Gervais	148
# 		Russell Brand	145
# Community 7
# 	Number of nodes: 3142 (%6.54), out of which, 412 are Trump followers (%5.04)
# 	Total number of friends: 10652
# 	Top 10 Friends of Trump's followers:
# 		Lil Wayne WEEZY F	161
# 		Sean Diddy Combs	125
# 		Chris Brown	113
# 		T.I.	112
# 		Trey Songz	111
# 		Alicia Keys	108
# 		J. Cole	108
# 		Ludacris	106
# 		Snoop Dogg	103
# 		Trevor Noah	101
# Community 12
# 	Number of nodes: 2738 (%5.70), out of which, 368 are Trump followers (%4.50)
# 	Total number of friends: 11173
# 	Top 10 Friends of Trump's followers:
# 		PlayStation	102
# 		Xbox	102
# 		Dwayne Johnson	90
# 		Rockstar Games	86
# 		John Cena	85
# 		Steam	79
# 		WWE	76
# 		Triple H	72
# 		Steve Austin	71
# 		Ubisoft	71
# Community 11
# 	Number of nodes: 1635 (%3.41), out of which, 250 are Trump followers (%3.06)
# 	Total number of friends: 6036
# 	Top 10 Friends of Trump's followers:
# 		Channels Television	90
# 		Uhuru Kenyatta	82
# 		Sahara Reporters	81
# 		Premier League	78
# 		Linda Ikeji	77
# 		Prof Yemi Osinbajo	74
# 		The Punch Newspapers	74
# 		Piers Morgan	72
# 		NTV Kenya	68
# 		Davido	68
# Community 15
# 	Number of nodes: 1053 (%2.19), out of which, 142 are Trump followers (%1.74)
# 	Total number of friends: 3555
# 	Top 10 Friends of Trump's followers:
# 		العربية عاجل	99
# 		قناة العربية	95
# 		أحمد الشقيري	91
# 		قناة الجزيرة	90
# 		CNN بالعربية	80
# 		د. #عائض_القرني	72
# 		Nancy Ajram	72
# 		Elissa	71
# 		مشاري راشد العفاسي	68
# 		Kendall	67
# Community 10
# 	Number of nodes: 1175 (%2.45), out of which, 136 are Trump followers (%1.66)
# 	Total number of friends: 4744
# 	Top 10 Friends of Trump's followers:
# 		Justin Trudeau	37
# 		Bloomberg	34
# 		Jim Cramer	33
# 		CBC News	30
# 		Stephen Harper	28
# 		CNBC	28
# 		The Associated Press	27
# 		Breaking News	26
# 		The Globe and Mail	26
# 		Mark Cuban	25
# Community 17
# 	Number of nodes: 582 (%1.21), out of which, 100 are Trump followers (%1.22)
# 	Total number of friends: 2053
# 	Top 10 Friends of Trump's followers:
# 		Kylie Jenner	41
# 		Ariana Grande	40
# 		Kendall	39
# 		VEJA	37
# 		Marcelo Tas	35
# 		G1	34
# 		Jornal O Globo	33
# 		Stephen Colbert	33
# 		Estadão	33
# 		Folha de S.Paulo	32
# Community 13
# 	Number of nodes: 532 (%1.11), out of which, 98 are Trump followers (%1.20)
# 	Total number of friends: 1897
# 	Top 10 Friends of Trump's followers:
# 		detikcom	61
# 		AGNEZ MO	55
# 		METRO TV	51
# 		TMC Polda Metro Jaya	50
# 		UberSocial	49
# 		tvOneNews	48
# 		S. B. Yudhoyono	47
# 		Kompas.com	47
# 		Joko Widodo	47
# 		luna maya	46
# Community 8
# 	Number of nodes: 344 (%0.72), out of which, 65 are Trump followers (%0.79)
# 	Total number of friends: 1859
# 	Top 10 Friends of Trump's followers:
# 		Angel Locsin	53
# 		PAGASA-DOST	46
# 		GMA News	46
# 		ABS-CBN News	45
# 		KC Concepcion	43
# 		Bianca Gonzalez	43
# 		jose marie viceral	43
# 		ABS-CBN News Channel	41
# 		MYX Philippines	41
# 		Yeng Constantino	40
# Community 9
# 	Number of nodes: 177 (%0.37), out of which, 36 are Trump followers (%0.44)
# 	Total number of friends: 705
# 	Top 10 Friends of Trump's followers:
# 		Ariana Grande	22
# 		美国驻华使领馆 US MissionCN	21
# 		Kendall	19
# 		Kai-Fu Lee	19
# 		纽约时报中文网	19
# 		BBC Chinese	19
# 		Kylie Jenner	18
# 		Fresh Stories	18
# 		我们爱讲冷笑话	18
# 		华尔街日报中文网	18
# Community 2
# 	Number of nodes: 264 (%0.55), out of which, 32 are Trump followers (%0.39)
# 	Total number of friends: 1463
# 	Top 10 Friends of Trump's followers:
# 		Malcolm Turnbull	22
# 		ABC News	18
# 		Julia Gillard	14
# 		The Age	14
# 		smh.com.au	13
# 		Tony Abbott	13
# 		Kevin Rudd	13
# 		AFL	13
# 		Rove McManus	13
# 		Dave Hughes	12
# Community 14
# 	Number of nodes: 330 (%0.69), out of which, 20 are Trump followers (%0.24)
# 	Total number of friends: 570
# 	Top 10 Friends of Trump's followers:
# 		Ebrahim Hemmatnia	13
# 		Richard Thomas	13
# 		David Copperfield	13
# 		Dr Elio Keller	13
# 		Angel Rivera	13
# 		Rick G. Rosner	12
# 		bonno van der putten	12
# 		Morris Chestnut	12
# 		Uncle Louie G	12
# 		LeBron James ☄	12
# Community 3
# 	Number of nodes: 93 (%0.19), out of which, 18 are Trump followers (%0.22)
# 	Total number of friends: 485
# 	Top 10 Friends of Trump's followers:
# 		Kemal Kılıçdaroğlu	14
# 		Cem Yılmaz	14
# 		ahmet hakan	14
# 		cüneyt özdemir	14
# 		NTV	13
# 		Hurriyet.com.tr	12
# 		Recep Tayyip Erdoğan	12
# 		Abdullah Gül	12
# 		Hürriyet Gündem	12
# 		CNN Türk	11
# Community 16
# 	Number of nodes: 70 (%0.15), out of which, 15 are Trump followers (%0.18)
# 	Total number of friends: 276
# 	Top 10 Friends of Trump's followers:
# 		Opal Panisara	13
# 		JS100	13
# 		Woody Milintachinda	13
# 		Andrew Biggs	13
# 		V.Vajiramedhi	12
# 		Major Cineplex	12
# 		Thairath_News	12
# 		cuttO	11
# 		สมาคมมุขเสี่ยวๆ	11
# 		เรื่องเล่าเช้านี้	11
